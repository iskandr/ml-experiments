# %%
import jax
f =

# %%
f(key=jax.random.PRNGKey(42), shape=(10,20))
# Out:
# /usr/local/lib/python3.7/site-packages/jax/lib/xla_bridge.py:130: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')
# DeviceArray([[-2.40535080e-01,  2.09496006e-01,  2.73170203e-01,
#               -1.83235005e-01, -2.98433632e-01, -5.75518832e-02,
#                2.95001328e-01,  2.84294903e-01, -1.09801762e-01,
#                1.22004651e-01, -7.18781129e-02, -1.38199970e-01,
#                7.64145609e-03, -1.25468373e-01,  2.19576985e-01,
#                1.94912422e-02,  6.07903861e-02,  5.58274388e-02,
#                1.18682109e-01,  4.01209183e-02],
#              [-2.01150343e-01,  1.87131926e-01, -4.31719609e-02,
#                1.07452735e-01,  1.39579803e-01,  2.22268030e-01,
#                4.74398524e-01,  1.06911749e-01,  1.91788711e-02,
#               -1.73415646e-01,  3.26483534e-03, -1.07496321e-01,
#               -1.50849640e-01,  7.54011981e-03,  2.58213520e-01,
# ...
